# %% [markdown]
# <a href="https://colab.research.google.com/github/kishenvir/Test/blob/main/Day_4_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
