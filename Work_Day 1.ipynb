# %% [markdown]
# <a href="https://colab.research.google.com/github/kishenvir/Test/blob/main/Work_Day%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Hello = "Kishen"
print(Hello)
# Out:
# Kishen

# %%
a=10
print(a)
# Out:
# 10

# %% [markdown]
# This was an example for variable declaration

# %%
import random 
print (random.sample(range(5,20),6))
# Out:
# [10, 12, 6, 13, 11, 18]

# %%
import math 
import random
print(math.sqrt(9))
print(math.sqrt(16))
print (int(math.sqrt(100)))
print (math.degrees(math.pi))
print (float(random.randint(4,7)))
# Out:
# 3.0
# 4.0
# 10
# 180.0
# 6.0
